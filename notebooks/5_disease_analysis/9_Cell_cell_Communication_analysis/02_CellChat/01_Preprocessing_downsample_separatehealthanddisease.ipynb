# %% [markdown]
# ### Cell-cell interaction analysis of MUC6 cells
# Want to analyse cell-cell interactions with cell chat (in R)
# - with full counts disease MUC6 cells vs all
# - with less counts (more cells) disease MUC6 cells vs all
# --> in all cases downsample to 100 cells per donor per cell type? or 50? See how many cells I get - analysis should be only on adult

# %%
import scanpy as sc
import pandas as pd
import numpy as np
import sys
import os
from collections import Counter

import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import to_hex
import ast

# %%
import random

# %%
sc.logging.print_header()
# Out:
# scanpy==1.7.1 anndata==0.8.0 umap==0.4.6 numpy==1.20.1 scipy==1.6.1 pandas==1.2.3 scikit-learn==0.24.1 statsmodels==0.12.2 python-igraph==0.8.3 louvain==0.7.0 leidenalg==0.8.3

# %%
ad1 = sc.read_h5ad('/nfs/team205/ao15/Megagut/Annotations_v3/h5ad/pooled_healthy_disease.remapped.allgenes.fine_annot.no_doublets.20230322.h5ad')

# %%
ad1
# Out:
# AnnData object with n_obs × n_vars = 1358576 × 36601
#     var: 'gene_ids', 'feature_type', 'mito', 'ribo', 'hb', 'cc', 'ig', 'tcr', 'n_counts-0', 'n_counts_raw-0', 'n_counts_spliced-0', 'n_counts_unspliced-0', 'n_cells-0', 'n_cells_raw-0', 'n_cells_spliced-0', 'n_cells_unspliced-0', 'n_counts-1', 'n_counts_raw-1', 'n_counts_spliced-1', 'n_counts_unspliced-1', 'n_cells-1', 'n_cells_raw-1', 'n_cells_spliced-1', 'n_cells_unspliced-1'
#     uns: 'age_unified_colors', 'control_vs_disease_colors', 'disease_colors', 'level_1_annot_colors', 'level_3_annot_colors', 'neighbors', 'organ_groups_colors', 'organ_unified_colors', 'study_colors', 'umap'
#     obsm: 'X_mde', 'X_scANVI', 'X_umap', '_scvi_extra_continuous_covs'
#     obsp: 'connectivities', 'distances'

# %%
#function for downsampling
def downsample_mask(clustering, to_thin, n_cells=200):
    mask = np.array([i not in to_thin for i in clustering])
    numtemp = np.arange(len(clustering))
    for clus in to_thin:
        inds = set(numtemp[[i==clus for i in clustering]])
        keep = random.sample(inds, round(n_cells))
        mask[keep] = True
    return mask

# %%
ad1.obs = pd.read_csv('/nfs/team205/ao15/Megagut/Annotations_v3/metadata/pooled_healthy_disease.remapped.allgenes.fine_annot.no_doublets.20230322.csv',index_col=0)
# Out:
# /home/jovyan/my-conda-envs/standard/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (73,82,83,84,86,93,102,105,112,113,114,115,117,119) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
ad1
# Out:
# AnnData object with n_obs × n_vars = 1358576 × 36601
#     obs: 'latent_cell_probability', 'latent_RT_efficiency', 'cecilia22_predH', 'cecilia22_predH_prob', 'cecilia22_predH_uncertain', 'cecilia22_predL', 'cecilia22_predL_prob', 'cecilia22_predL_uncertain', 'elmentaite21_pred', 'elmentaite21_pred_prob', 'elmentaite21_pred_uncertain', 'suo22_pred', 'suo22_pred_prob', 'suo22_pred_uncertain', 'n_counts', 'log1p_n_counts', 'n_genes', 'log1p_n_genes', 'percent_mito', 'n_counts_mito', 'percent_ribo', 'n_counts_ribo', 'percent_hb', 'n_counts_hb', 'percent_top50', 'n_counts_raw', 'log1p_n_counts_raw', 'n_genes_raw', 'log1p_n_genes_raw', 'percent_mito_raw', 'n_counts_mito_raw', 'percent_ribo_raw', 'n_counts_ribo_raw', 'percent_hb_raw', 'n_counts_hb_raw', 'percent_top50_raw', 'n_counts_spliced', 'log1p_n_counts_spliced', 'n_genes_spliced', 'log1p_n_genes_spliced', 'percent_mito_spliced', 'n_counts_mito_spliced', 'percent_ribo_spliced', 'n_counts_ribo_spliced', 'percent_hb_spliced', 'n_counts_hb_spliced', 'percent_top50_spliced', 'n_counts_unspliced', 'log1p_n_counts_unspliced', 'n_genes_unspliced', 'log1p_n_genes_unspliced', 'percent_mito_unspliced', 'n_counts_mito_unspliced', 'percent_ribo_unspliced', 'n_counts_ribo_unspliced', 'percent_hb_unspliced', 'n_counts_hb_unspliced', 'percent_top50_unspliced', 'percent_soup', 'percent_spliced', 'qc_cluster', 'pass_auto_filter_mito20', 'good_qc_cluster_mito20', 'pass_auto_filter_mito50', 'good_qc_cluster_mito50', 'pass_auto_filter_mito80', 'good_qc_cluster_mito80', 'pass_auto_filter', 'good_qc_cluster', 'pass_default', 'sampleID', 'sourceID', 'donorID_original', 'study', 'donorID_corrected', 'donorID_unified', 'donor_category', 'donor_disease', 'organ_original', 'organ_unified', 'organ_broad', 'age_original', 'age_unified', 'age_continuousadult', 'age_continuousdev', 'sex', 'sample_type', 'sample_category', 'sample_retrieval', 'tissue_fraction', 'cell_fraction', 'cell_fraction_unified', 'cell_sorting', 'technology', 'include_150722', 'cluster_scrublet_score', 'bh_pval', 'scrublet_score', 'scrublet_score_z', 'doublet', 'stringent_doublet', 'integration_grouping', '_scvi_batch', '_scvi_labels', 'broad_annot_20220914', 'martin19_pred', 'martin19_pred_prob', 'martin19_pred_uncertain', 'warner20_pred', 'warner20_pred_prob', 'warner20_pred_uncertain', 'broad_annot_20220917', 'donor_organ_lineage', 'fine_annot', 'fine_annot_original', 'level_1_annot', 'level_2_annot', 'level_3_annot', 'broad_predicted_labels', 'broad_predicted_labels_uncert', 'batch', 'organ_groups', 'control_vs_disease', 'disease'
#     var: 'gene_ids', 'feature_type', 'mito', 'ribo', 'hb', 'cc', 'ig', 'tcr', 'n_counts-0', 'n_counts_raw-0', 'n_counts_spliced-0', 'n_counts_unspliced-0', 'n_cells-0', 'n_cells_raw-0', 'n_cells_spliced-0', 'n_cells_unspliced-0', 'n_counts-1', 'n_counts_raw-1', 'n_counts_spliced-1', 'n_counts_unspliced-1', 'n_cells-1', 'n_cells_raw-1', 'n_cells_spliced-1', 'n_cells_unspliced-1'
#     uns: 'age_unified_colors', 'control_vs_disease_colors', 'disease_colors', 'level_1_annot_colors', 'level_3_annot_colors', 'neighbors', 'organ_groups_colors', 'organ_unified_colors', 'study_colors', 'umap'
#     obsm: 'X_mde', 'X_scANVI', 'X_umap', '_scvi_extra_continuous_covs'
#     obsp: 'connectivities', 'distances'

# %%
ad1.obs.disease.value_counts()
# Out:
# control                   489029
# inutero                   333624
# neighbouring_cancer       152292
# cancer_gastric            101594
# neighbouring_inflammed     77136
# pediatric_IBD              67092
# crohns_disease             48074
# ulcerative_colitis         35891
# cancer_colorectal          28684
# neighbouring_polyps        15648
# preterm                     9512
# Name: disease, dtype: int64

# %%
ad1 = ad1[~ad1.obs.disease.isin(['inutero','preterm'])].copy()

# %%
ad1.X.max()
# Out:
# 40699.0

# %%
sc.pp.normalize_per_cell(ad1, counts_per_cell_after=1e4)
sc.pp.log1p(ad1)

# %%
ad1.X.max()
# Out:
# 9.180252

# %%
#Prepare categories for downsampling (per donor_celltype combination)
ad1.obs['donor_celltype']=ad1.obs['donorID_unified'].astype(str)+'_'+ad1.obs['level_3_annot'].astype(str)
ad1.obs.donor_celltype.value_counts()
# Out:
# D55_Keratinocyte_stratified    14295
# D56_Keratinocyte_stratified    11511
# D58_Keratinocyte_stratified    10007
# D54_Keratinocyte_stratified     8921
# D11_Colonocyte                  7335
#                                ...
# D147_DC_langerhans                 1
# D12_Microfold                      1
# D158_B_plasmablast                 1
# D11_DCS_MUC17                      1
# D119_Myofibroblast                 1
# Name: donor_celltype, Length: 7827, dtype: int64

# %%
#Downsample to 50 cells per cell type per donor
vc=ad1.obs.donor_celltype.value_counts().loc[lambda x: x>50].reset_index()['index']
mask_p = downsample_mask(ad1.obs['donor_celltype'], vc.tolist(), n_cells=50)
ad1 = ad1[mask_p]
ad1.obs.donor_celltype.value_counts()
# Out:
# Dpool3_gdT                       50
# D97_B_plasma_IgG                 50
# D12_gdT                          50
# D141_Treg                        50
# D41_T/NK_cycling                 50
#                                  ..
# D46_Goblet                        1
# D94_Enteroendocrine_MX            1
# Dpool3_Oral_mucosa_fibroblast     1
# D137_Colonocyte                   1
# D50_Tfh                           1
# Name: donor_celltype, Length: 7827, dtype: int64

# %%
ad1
# Out:
# View of AnnData object with n_obs × n_vars = 192141 × 36601
#     obs: 'latent_cell_probability', 'latent_RT_efficiency', 'cecilia22_predH', 'cecilia22_predH_prob', 'cecilia22_predH_uncertain', 'cecilia22_predL', 'cecilia22_predL_prob', 'cecilia22_predL_uncertain', 'elmentaite21_pred', 'elmentaite21_pred_prob', 'elmentaite21_pred_uncertain', 'suo22_pred', 'suo22_pred_prob', 'suo22_pred_uncertain', 'n_counts', 'log1p_n_counts', 'n_genes', 'log1p_n_genes', 'percent_mito', 'n_counts_mito', 'percent_ribo', 'n_counts_ribo', 'percent_hb', 'n_counts_hb', 'percent_top50', 'n_counts_raw', 'log1p_n_counts_raw', 'n_genes_raw', 'log1p_n_genes_raw', 'percent_mito_raw', 'n_counts_mito_raw', 'percent_ribo_raw', 'n_counts_ribo_raw', 'percent_hb_raw', 'n_counts_hb_raw', 'percent_top50_raw', 'n_counts_spliced', 'log1p_n_counts_spliced', 'n_genes_spliced', 'log1p_n_genes_spliced', 'percent_mito_spliced', 'n_counts_mito_spliced', 'percent_ribo_spliced', 'n_counts_ribo_spliced', 'percent_hb_spliced', 'n_counts_hb_spliced', 'percent_top50_spliced', 'n_counts_unspliced', 'log1p_n_counts_unspliced', 'n_genes_unspliced', 'log1p_n_genes_unspliced', 'percent_mito_unspliced', 'n_counts_mito_unspliced', 'percent_ribo_unspliced', 'n_counts_ribo_unspliced', 'percent_hb_unspliced', 'n_counts_hb_unspliced', 'percent_top50_unspliced', 'percent_soup', 'percent_spliced', 'qc_cluster', 'pass_auto_filter_mito20', 'good_qc_cluster_mito20', 'pass_auto_filter_mito50', 'good_qc_cluster_mito50', 'pass_auto_filter_mito80', 'good_qc_cluster_mito80', 'pass_auto_filter', 'good_qc_cluster', 'pass_default', 'sampleID', 'sourceID', 'donorID_original', 'study', 'donorID_corrected', 'donorID_unified', 'donor_category', 'donor_disease', 'organ_original', 'organ_unified', 'organ_broad', 'age_original', 'age_unified', 'age_continuousadult', 'age_continuousdev', 'sex', 'sample_type', 'sample_category', 'sample_retrieval', 'tissue_fraction', 'cell_fraction', 'cell_fraction_unified', 'cell_sorting', 'technology', 'include_150722', 'cluster_scrublet_score', 'bh_pval', 'scrublet_score', 'scrublet_score_z', 'doublet', 'stringent_doublet', 'integration_grouping', '_scvi_batch', '_scvi_labels', 'broad_annot_20220914', 'martin19_pred', 'martin19_pred_prob', 'martin19_pred_uncertain', 'warner20_pred', 'warner20_pred_prob', 'warner20_pred_uncertain', 'broad_annot_20220917', 'donor_organ_lineage', 'fine_annot', 'fine_annot_original', 'level_1_annot', 'level_2_annot', 'level_3_annot', 'broad_predicted_labels', 'broad_predicted_labels_uncert', 'batch', 'organ_groups', 'control_vs_disease', 'disease', 'donor_celltype'
#     var: 'gene_ids', 'feature_type', 'mito', 'ribo', 'hb', 'cc', 'ig', 'tcr', 'n_counts-0', 'n_counts_raw-0', 'n_counts_spliced-0', 'n_counts_unspliced-0', 'n_cells-0', 'n_cells_raw-0', 'n_cells_spliced-0', 'n_cells_unspliced-0', 'n_counts-1', 'n_counts_raw-1', 'n_counts_spliced-1', 'n_counts_unspliced-1', 'n_cells-1', 'n_cells_raw-1', 'n_cells_spliced-1', 'n_cells_unspliced-1'
#     uns: 'age_unified_colors', 'control_vs_disease_colors', 'disease_colors', 'level_1_annot_colors', 'level_3_annot_colors', 'neighbors', 'organ_groups_colors', 'organ_unified_colors', 'study_colors', 'umap', 'log1p'
#     obsm: 'X_mde', 'X_scANVI', 'X_umap', '_scvi_extra_continuous_covs'
#     obsp: 'connectivities', 'distances'

# %%
ad1.obs.organ_groups.value_counts()
# Out:
# Large_intestine    55257
# Small_intestine    51700
# Stomach            50606
# Oral_mucosa        23181
# Oesophagus          5958
# Salivary_gland      5439
# Name: organ_groups, dtype: int64

# %%
#filter to cells in small intestine only
ad1 = ad1[ad1.obs.organ_groups.isin(['Small_intestine'])].copy()

# %%
ad1
# Out:
# AnnData object with n_obs × n_vars = 51700 × 36601
#     obs: 'latent_cell_probability', 'latent_RT_efficiency', 'cecilia22_predH', 'cecilia22_predH_prob', 'cecilia22_predH_uncertain', 'cecilia22_predL', 'cecilia22_predL_prob', 'cecilia22_predL_uncertain', 'elmentaite21_pred', 'elmentaite21_pred_prob', 'elmentaite21_pred_uncertain', 'suo22_pred', 'suo22_pred_prob', 'suo22_pred_uncertain', 'n_counts', 'log1p_n_counts', 'n_genes', 'log1p_n_genes', 'percent_mito', 'n_counts_mito', 'percent_ribo', 'n_counts_ribo', 'percent_hb', 'n_counts_hb', 'percent_top50', 'n_counts_raw', 'log1p_n_counts_raw', 'n_genes_raw', 'log1p_n_genes_raw', 'percent_mito_raw', 'n_counts_mito_raw', 'percent_ribo_raw', 'n_counts_ribo_raw', 'percent_hb_raw', 'n_counts_hb_raw', 'percent_top50_raw', 'n_counts_spliced', 'log1p_n_counts_spliced', 'n_genes_spliced', 'log1p_n_genes_spliced', 'percent_mito_spliced', 'n_counts_mito_spliced', 'percent_ribo_spliced', 'n_counts_ribo_spliced', 'percent_hb_spliced', 'n_counts_hb_spliced', 'percent_top50_spliced', 'n_counts_unspliced', 'log1p_n_counts_unspliced', 'n_genes_unspliced', 'log1p_n_genes_unspliced', 'percent_mito_unspliced', 'n_counts_mito_unspliced', 'percent_ribo_unspliced', 'n_counts_ribo_unspliced', 'percent_hb_unspliced', 'n_counts_hb_unspliced', 'percent_top50_unspliced', 'percent_soup', 'percent_spliced', 'qc_cluster', 'pass_auto_filter_mito20', 'good_qc_cluster_mito20', 'pass_auto_filter_mito50', 'good_qc_cluster_mito50', 'pass_auto_filter_mito80', 'good_qc_cluster_mito80', 'pass_auto_filter', 'good_qc_cluster', 'pass_default', 'sampleID', 'sourceID', 'donorID_original', 'study', 'donorID_corrected', 'donorID_unified', 'donor_category', 'donor_disease', 'organ_original', 'organ_unified', 'organ_broad', 'age_original', 'age_unified', 'age_continuousadult', 'age_continuousdev', 'sex', 'sample_type', 'sample_category', 'sample_retrieval', 'tissue_fraction', 'cell_fraction', 'cell_fraction_unified', 'cell_sorting', 'technology', 'include_150722', 'cluster_scrublet_score', 'bh_pval', 'scrublet_score', 'scrublet_score_z', 'doublet', 'stringent_doublet', 'integration_grouping', '_scvi_batch', '_scvi_labels', 'broad_annot_20220914', 'martin19_pred', 'martin19_pred_prob', 'martin19_pred_uncertain', 'warner20_pred', 'warner20_pred_prob', 'warner20_pred_uncertain', 'broad_annot_20220917', 'donor_organ_lineage', 'fine_annot', 'fine_annot_original', 'level_1_annot', 'level_2_annot', 'level_3_annot', 'broad_predicted_labels', 'broad_predicted_labels_uncert', 'batch', 'organ_groups', 'control_vs_disease', 'disease', 'donor_celltype'
#     var: 'gene_ids', 'feature_type', 'mito', 'ribo', 'hb', 'cc', 'ig', 'tcr', 'n_counts-0', 'n_counts_raw-0', 'n_counts_spliced-0', 'n_counts_unspliced-0', 'n_cells-0', 'n_cells_raw-0', 'n_cells_spliced-0', 'n_cells_unspliced-0', 'n_counts-1', 'n_counts_raw-1', 'n_counts_spliced-1', 'n_counts_unspliced-1', 'n_cells-1', 'n_cells_raw-1', 'n_cells_spliced-1', 'n_cells_unspliced-1'
#     uns: 'age_unified_colors', 'control_vs_disease_colors', 'disease_colors', 'level_1_annot_colors', 'level_3_annot_colors', 'neighbors', 'organ_groups_colors', 'organ_unified_colors', 'study_colors', 'umap', 'log1p'
#     obsm: 'X_mde', 'X_scANVI', 'X_umap', '_scvi_extra_continuous_covs'
#     obsp: 'connectivities', 'distances'

# %%
df = pd.DataFrame(ad1.X.todense(), index=ad1.obs_names, columns=ad1.var_names)
#tranpose
df = df.T
df
# Out:
# index        AACCGCGCAGTTTACG-HCA_A_GT12934998  \
# MIR1302-2HG                                0.0
# FAM138A                                    0.0
# OR4F5                                      0.0
# AL627309.1                                 0.0
# AL627309.3                                 0.0
# ...                                        ...
# AC141272.1                                 0.0
# AC023491.2                                 0.0
# AC007325.1                                 0.0
# AC007325.4                                 0.0
# AC007325.2                                 0.0
#
# index        ACAGCTAGTTAGATGA-HCA_A_GT12934998  \
# MIR1302-2HG                                0.0
# FAM138A                                    0.0
# OR4F5                                      0.0
# AL627309.1                                 0.0
# AL627309.3                                 0.0
# ...                                        ...
# AC141272.1                                 0.0
# AC023491.2                                 0.0
# AC007325.1                                 0.0
# AC007325.4                                 0.0
# AC007325.2                                 0.0
#
# index        ACCAGTAGTCAAGCGA-HCA_A_GT12934998  \
# MIR1302-2HG                                0.0
# FAM138A                                    0.0
# OR4F5                                      0.0
# AL627309.1                                 0.0
# AL627309.3                                 0.0
# ...                                        ...
# AC141272.1                                 0.0
# AC023491.2                                 0.0
# AC007325.1                                 0.0
# AC007325.4                                 0.0
# AC007325.2                                 0.0
#
# index        ACGAGGATCGGTCTAA-HCA_A_GT12934998  \
# MIR1302-2HG                                0.0
# FAM138A                                    0.0
# OR4F5                                      0.0
# AL627309.1                                 0.0
# AL627309.3                                 0.0
# ...                                        ...
# AC141272.1                                 0.0
# AC023491.2                                 0.0
# AC007325.1                                 0.0
# AC007325.4                                 0.0
# AC007325.2                                 0.0
#
# index        ACGATGTTCCGAAGAG-HCA_A_GT12934998  \
# MIR1302-2HG                                0.0
# FAM138A                                    0.0
# OR4F5                                      0.0
# AL627309.1                                 0.0
# AL627309.3                                 0.0
# ...                                        ...
# AC141272.1                                 0.0
# AC023491.2                                 0.0
# AC007325.1                                 0.0
# AC007325.4                                 0.0
# AC007325.2                                 0.0
#
# index        ACGGGTCAGCTATGCT-HCA_A_GT12934998  \
# MIR1302-2HG                                0.0
# FAM138A                                    0.0
# OR4F5                                      0.0
# AL627309.1                                 0.0
# AL627309.3                                 0.0
# ...                                        ...
# AC141272.1                                 0.0
# AC023491.2                                 0.0
# AC007325.1                                 0.0
# AC007325.4                                 0.0
# AC007325.2                                 0.0
#
# index        ACTGCTCAGTCCAGGA-HCA_A_GT12934998  \
# MIR1302-2HG                                0.0
# FAM138A                                    0.0
# OR4F5                                      0.0
# AL627309.1                                 0.0
# AL627309.3                                 0.0
# ...                                        ...
# AC141272.1                                 0.0
# AC023491.2                                 0.0
# AC007325.1                                 0.0
# AC007325.4                                 0.0
# AC007325.2                                 0.0
#
# index        AGAATAGTCGTTGCCT-HCA_A_GT12934998  \
# MIR1302-2HG                                0.0
# FAM138A                                    0.0
# OR4F5                                      0.0
# AL627309.1                                 0.0
# AL627309.3                                 0.0
# ...                                        ...
# AC141272.1                                 0.0
# AC023491.2                                 0.0
# AC007325.1                                 0.0
# AC007325.4                                 0.0
# AC007325.2                                 0.0
#
# index        AGTGTCAGTAAGGGCT-HCA_A_GT12934998  \
# MIR1302-2HG                                0.0
# FAM138A                                    0.0
# OR4F5                                      0.0
# AL627309.1                                 0.0
# AL627309.3                                 0.0
# ...                                        ...
# AC141272.1                                 0.0
# AC023491.2                                 0.0
# AC007325.1                                 0.0
# AC007325.4                                 0.0
# AC007325.2                                 0.0
#
# index        ATCATCTTCTTGTATC-HCA_A_GT12934998  ...  \
# MIR1302-2HG                                0.0  ...
# FAM138A                                    0.0  ...
# OR4F5                                      0.0  ...
# AL627309.1                                 0.0  ...
# AL627309.3                                 0.0  ...
# ...                                        ...  ...
# AC141272.1                                 0.0  ...
# AC023491.2                                 0.0  ...
# AC007325.1                                 0.0  ...
# AC007325.4                                 0.0  ...
# AC007325.2                                 0.0  ...
#
# index        TGTGTTTTCTCCCTGA-GSM4766849  TTAGGACGTAAACGCG-GSM4766849  \
# MIR1302-2HG                          0.0                          0.0
# FAM138A                              0.0                          0.0
# OR4F5                                0.0                          0.0
# AL627309.1                           0.0                          0.0
# AL627309.3                           0.0                          0.0
# ...                                  ...                          ...
# AC141272.1                           0.0                          0.0
# AC023491.2                           0.0                          0.0
# AC007325.1                           0.0                          0.0
# AC007325.4                           0.0                          0.0
# AC007325.2                           0.0                          0.0
#
# index        TTAGGCACATGTCGAT-GSM4766849  TTCGAAGCATTGAGCT-GSM4766849  \
# MIR1302-2HG                          0.0                          0.0
# FAM138A                              0.0                          0.0
# OR4F5                                0.0                          0.0
# AL627309.1                           0.0                          0.0
# AL627309.3                           0.0                          0.0
# ...                                  ...                          ...
# AC141272.1                           0.0                          0.0
# AC023491.2                           0.0                          0.0
# AC007325.1                           0.0                          0.0
# AC007325.4                           0.0                          0.0
# AC007325.2                           0.0                          0.0
#
# index        TTCTCAAGTGAGCGAT-GSM4766849  TTGGCAACAGTGGAGT-GSM4766849  \
# MIR1302-2HG                          0.0                          0.0
# FAM138A                              0.0                          0.0
# OR4F5                                0.0                          0.0
# AL627309.1                           0.0                          0.0
# AL627309.3                           0.0                          0.0
# ...                                  ...                          ...
# AC141272.1                           0.0                          0.0
# AC023491.2                           0.0                          0.0
# AC007325.1                           0.0                          0.0
# AC007325.4                           0.0                          0.0
# AC007325.2                           0.0                          0.0
#
# index        TTGGCAAGTGCTAGCC-GSM4766849  TTGTAGGAGCCATCGC-GSM4766849  \
# MIR1302-2HG                          0.0                          0.0
# FAM138A                              0.0                          0.0
# OR4F5                                0.0                          0.0
# AL627309.1                           0.0                          0.0
# AL627309.3                           0.0                          0.0
# ...                                  ...                          ...
# AC141272.1                           0.0                          0.0
# AC023491.2                           0.0                          0.0
# AC007325.1                           0.0                          0.0
# AC007325.4                           0.0                          0.0
# AC007325.2                           0.0                          0.0
#
# index        TTGTAGGAGCTAGCCC-GSM4766849  TTTGGTTTCGGCCGAT-GSM4766849
# MIR1302-2HG                          0.0                          0.0
# FAM138A                              0.0                          0.0
# OR4F5                                0.0                          0.0
# AL627309.1                           0.0                          0.0
# AL627309.3                           0.0                          0.0
# ...                                  ...                          ...
# AC141272.1                           0.0                          0.0
# AC023491.2                           0.0                          0.0
# AC007325.1                           0.0                          0.0
# AC007325.4                           0.0                          0.0
# AC007325.2                           0.0                          0.0
#
# [36601 rows x 51700 columns]

# %%
df.to_csv('/home/jovyan/ao15/Megagut/Annotations_v3/disease_analysis/interactions/counts/pooled_healthy_disease.remapped.allgenes.AP_SI.counts.csv')

# %%
meta = ad1.obs.level_3_annot
meta
# Out:
# index
# AACCGCGCAGTTTACG-HCA_A_GT12934998                  Monocyte
# AACTCTTCAAGCTGAG-HCA_A_GT12934998             Tnaive/cm_CD8
# ACACTGAGTAACGCGA-HCA_A_GT12934998                      Treg
# ACGAGGATCGGTCTAA-HCA_A_GT12934998    Megakaryocyte/platelet
# ACTGCTCAGTCCAGGA-HCA_A_GT12934998                        TA
#                                               ...
# TTGAACGCAGTTAACC-GSM4766849                         NK_CD16
# TTGGCAACAGTGGAGT-GSM4766849                        Monocyte
# TTTACTGGTGGACGAT-GSM4766849                   NK_CD56bright
# TTTGGTTTCGGCCGAT-GSM4766849                      Enterocyte
# TTTGTCAAGTTACCCA-GSM4766849                    T/NK_cycling
# Name: level_3_annot, Length: 51766, dtype: object

# %%
meta.to_csv('/home/jovyan/ao15/Megagut/Annotations_v3/disease_analysis/interactions/meta/pooled_healthy_disease.remapped.allgenes.AP_SI.meta.csv')

# %%
ad1.obs.disease.value_counts()
# Out:
# control                   18889
# pediatric_IBD              9910
# crohns_disease             9744
# neighbouring_inflammed     8042
# neighbouring_polyps        4524
# neighbouring_cancer         657
# Name: disease, dtype: int64

# %%
healthy = ad1[ad1.obs.disease.isin(['control'])].copy()

# %%
disease = ad1[ad1.obs.disease.isin(['crohns_disease','pediatric_IBD'])].copy()

# %%
healthy
# Out:
# AnnData object with n_obs × n_vars = 18889 × 36601
#     obs: 'latent_cell_probability', 'latent_RT_efficiency', 'cecilia22_predH', 'cecilia22_predH_prob', 'cecilia22_predH_uncertain', 'cecilia22_predL', 'cecilia22_predL_prob', 'cecilia22_predL_uncertain', 'elmentaite21_pred', 'elmentaite21_pred_prob', 'elmentaite21_pred_uncertain', 'suo22_pred', 'suo22_pred_prob', 'suo22_pred_uncertain', 'n_counts', 'log1p_n_counts', 'n_genes', 'log1p_n_genes', 'percent_mito', 'n_counts_mito', 'percent_ribo', 'n_counts_ribo', 'percent_hb', 'n_counts_hb', 'percent_top50', 'n_counts_raw', 'log1p_n_counts_raw', 'n_genes_raw', 'log1p_n_genes_raw', 'percent_mito_raw', 'n_counts_mito_raw', 'percent_ribo_raw', 'n_counts_ribo_raw', 'percent_hb_raw', 'n_counts_hb_raw', 'percent_top50_raw', 'n_counts_spliced', 'log1p_n_counts_spliced', 'n_genes_spliced', 'log1p_n_genes_spliced', 'percent_mito_spliced', 'n_counts_mito_spliced', 'percent_ribo_spliced', 'n_counts_ribo_spliced', 'percent_hb_spliced', 'n_counts_hb_spliced', 'percent_top50_spliced', 'n_counts_unspliced', 'log1p_n_counts_unspliced', 'n_genes_unspliced', 'log1p_n_genes_unspliced', 'percent_mito_unspliced', 'n_counts_mito_unspliced', 'percent_ribo_unspliced', 'n_counts_ribo_unspliced', 'percent_hb_unspliced', 'n_counts_hb_unspliced', 'percent_top50_unspliced', 'percent_soup', 'percent_spliced', 'qc_cluster', 'pass_auto_filter_mito20', 'good_qc_cluster_mito20', 'pass_auto_filter_mito50', 'good_qc_cluster_mito50', 'pass_auto_filter_mito80', 'good_qc_cluster_mito80', 'pass_auto_filter', 'good_qc_cluster', 'pass_default', 'sampleID', 'sourceID', 'donorID_original', 'study', 'donorID_corrected', 'donorID_unified', 'donor_category', 'donor_disease', 'organ_original', 'organ_unified', 'organ_broad', 'age_original', 'age_unified', 'age_continuousadult', 'age_continuousdev', 'sex', 'sample_type', 'sample_category', 'sample_retrieval', 'tissue_fraction', 'cell_fraction', 'cell_fraction_unified', 'cell_sorting', 'technology', 'include_150722', 'cluster_scrublet_score', 'bh_pval', 'scrublet_score', 'scrublet_score_z', 'doublet', 'stringent_doublet', 'integration_grouping', '_scvi_batch', '_scvi_labels', 'broad_annot_20220914', 'martin19_pred', 'martin19_pred_prob', 'martin19_pred_uncertain', 'warner20_pred', 'warner20_pred_prob', 'warner20_pred_uncertain', 'broad_annot_20220917', 'donor_organ_lineage', 'fine_annot', 'fine_annot_original', 'level_1_annot', 'level_2_annot', 'level_3_annot', 'broad_predicted_labels', 'broad_predicted_labels_uncert', 'batch', 'organ_groups', 'control_vs_disease', 'disease', 'donor_celltype'
#     var: 'gene_ids', 'feature_type', 'mito', 'ribo', 'hb', 'cc', 'ig', 'tcr', 'n_counts-0', 'n_counts_raw-0', 'n_counts_spliced-0', 'n_counts_unspliced-0', 'n_cells-0', 'n_cells_raw-0', 'n_cells_spliced-0', 'n_cells_unspliced-0', 'n_counts-1', 'n_counts_raw-1', 'n_counts_spliced-1', 'n_counts_unspliced-1', 'n_cells-1', 'n_cells_raw-1', 'n_cells_spliced-1', 'n_cells_unspliced-1'
#     uns: 'age_unified_colors', 'control_vs_disease_colors', 'disease_colors', 'level_1_annot_colors', 'level_3_annot_colors', 'neighbors', 'organ_groups_colors', 'organ_unified_colors', 'study_colors', 'umap', 'log1p'
#     obsm: 'X_mde', 'X_scANVI', 'X_umap', '_scvi_extra_continuous_covs'
#     obsp: 'connectivities', 'distances'

# %%
disease
# Out:
# AnnData object with n_obs × n_vars = 19654 × 36601
#     obs: 'latent_cell_probability', 'latent_RT_efficiency', 'cecilia22_predH', 'cecilia22_predH_prob', 'cecilia22_predH_uncertain', 'cecilia22_predL', 'cecilia22_predL_prob', 'cecilia22_predL_uncertain', 'elmentaite21_pred', 'elmentaite21_pred_prob', 'elmentaite21_pred_uncertain', 'suo22_pred', 'suo22_pred_prob', 'suo22_pred_uncertain', 'n_counts', 'log1p_n_counts', 'n_genes', 'log1p_n_genes', 'percent_mito', 'n_counts_mito', 'percent_ribo', 'n_counts_ribo', 'percent_hb', 'n_counts_hb', 'percent_top50', 'n_counts_raw', 'log1p_n_counts_raw', 'n_genes_raw', 'log1p_n_genes_raw', 'percent_mito_raw', 'n_counts_mito_raw', 'percent_ribo_raw', 'n_counts_ribo_raw', 'percent_hb_raw', 'n_counts_hb_raw', 'percent_top50_raw', 'n_counts_spliced', 'log1p_n_counts_spliced', 'n_genes_spliced', 'log1p_n_genes_spliced', 'percent_mito_spliced', 'n_counts_mito_spliced', 'percent_ribo_spliced', 'n_counts_ribo_spliced', 'percent_hb_spliced', 'n_counts_hb_spliced', 'percent_top50_spliced', 'n_counts_unspliced', 'log1p_n_counts_unspliced', 'n_genes_unspliced', 'log1p_n_genes_unspliced', 'percent_mito_unspliced', 'n_counts_mito_unspliced', 'percent_ribo_unspliced', 'n_counts_ribo_unspliced', 'percent_hb_unspliced', 'n_counts_hb_unspliced', 'percent_top50_unspliced', 'percent_soup', 'percent_spliced', 'qc_cluster', 'pass_auto_filter_mito20', 'good_qc_cluster_mito20', 'pass_auto_filter_mito50', 'good_qc_cluster_mito50', 'pass_auto_filter_mito80', 'good_qc_cluster_mito80', 'pass_auto_filter', 'good_qc_cluster', 'pass_default', 'sampleID', 'sourceID', 'donorID_original', 'study', 'donorID_corrected', 'donorID_unified', 'donor_category', 'donor_disease', 'organ_original', 'organ_unified', 'organ_broad', 'age_original', 'age_unified', 'age_continuousadult', 'age_continuousdev', 'sex', 'sample_type', 'sample_category', 'sample_retrieval', 'tissue_fraction', 'cell_fraction', 'cell_fraction_unified', 'cell_sorting', 'technology', 'include_150722', 'cluster_scrublet_score', 'bh_pval', 'scrublet_score', 'scrublet_score_z', 'doublet', 'stringent_doublet', 'integration_grouping', '_scvi_batch', '_scvi_labels', 'broad_annot_20220914', 'martin19_pred', 'martin19_pred_prob', 'martin19_pred_uncertain', 'warner20_pred', 'warner20_pred_prob', 'warner20_pred_uncertain', 'broad_annot_20220917', 'donor_organ_lineage', 'fine_annot', 'fine_annot_original', 'level_1_annot', 'level_2_annot', 'level_3_annot', 'broad_predicted_labels', 'broad_predicted_labels_uncert', 'batch', 'organ_groups', 'control_vs_disease', 'disease', 'donor_celltype'
#     var: 'gene_ids', 'feature_type', 'mito', 'ribo', 'hb', 'cc', 'ig', 'tcr', 'n_counts-0', 'n_counts_raw-0', 'n_counts_spliced-0', 'n_counts_unspliced-0', 'n_cells-0', 'n_cells_raw-0', 'n_cells_spliced-0', 'n_cells_unspliced-0', 'n_counts-1', 'n_counts_raw-1', 'n_counts_spliced-1', 'n_counts_unspliced-1', 'n_cells-1', 'n_cells_raw-1', 'n_cells_spliced-1', 'n_cells_unspliced-1'
#     uns: 'age_unified_colors', 'control_vs_disease_colors', 'disease_colors', 'level_1_annot_colors', 'level_3_annot_colors', 'neighbors', 'organ_groups_colors', 'organ_unified_colors', 'study_colors', 'umap', 'log1p'
#     obsm: 'X_mde', 'X_scANVI', 'X_umap', '_scvi_extra_continuous_covs'
#     obsp: 'connectivities', 'distances'

# %%
df = pd.DataFrame(healthy.X.todense(), index=healthy.obs_names, columns=healthy.var_names)
#tranpose
df = df.T
df
# Out:
# index        AACCGCGCAGTTTACG-HCA_A_GT12934998  \
# MIR1302-2HG                                0.0
# FAM138A                                    0.0
# OR4F5                                      0.0
# AL627309.1                                 0.0
# AL627309.3                                 0.0
# ...                                        ...
# AC141272.1                                 0.0
# AC023491.2                                 0.0
# AC007325.1                                 0.0
# AC007325.4                                 0.0
# AC007325.2                                 0.0
#
# index        AACTCTTCAAGCTGAG-HCA_A_GT12934998  \
# MIR1302-2HG                                0.0
# FAM138A                                    0.0
# OR4F5                                      0.0
# AL627309.1                                 0.0
# AL627309.3                                 0.0
# ...                                        ...
# AC141272.1                                 0.0
# AC023491.2                                 0.0
# AC007325.1                                 0.0
# AC007325.4                                 0.0
# AC007325.2                                 0.0
#
# index        ACACTGAGTAACGCGA-HCA_A_GT12934998  \
# MIR1302-2HG                                0.0
# FAM138A                                    0.0
# OR4F5                                      0.0
# AL627309.1                                 0.0
# AL627309.3                                 0.0
# ...                                        ...
# AC141272.1                                 0.0
# AC023491.2                                 0.0
# AC007325.1                                 0.0
# AC007325.4                                 0.0
# AC007325.2                                 0.0
#
# index        ACGAGGATCGGTCTAA-HCA_A_GT12934998  \
# MIR1302-2HG                                0.0
# FAM138A                                    0.0
# OR4F5                                      0.0
# AL627309.1                                 0.0
# AL627309.3                                 0.0
# ...                                        ...
# AC141272.1                                 0.0
# AC023491.2                                 0.0
# AC007325.1                                 0.0
# AC007325.4                                 0.0
# AC007325.2                                 0.0
#
# index        ACTGCTCAGTCCAGGA-HCA_A_GT12934998  \
# MIR1302-2HG                                0.0
# FAM138A                                    0.0
# OR4F5                                      0.0
# AL627309.1                                 0.0
# AL627309.3                                 0.0
# ...                                        ...
# AC141272.1                                 0.0
# AC023491.2                                 0.0
# AC007325.1                                 0.0
# AC007325.4                                 0.0
# AC007325.2                                 0.0
#
# index        AGAATAGTCGTTGCCT-HCA_A_GT12934998  \
# MIR1302-2HG                                0.0
# FAM138A                                    0.0
# OR4F5                                      0.0
# AL627309.1                                 0.0
# AL627309.3                                 0.0
# ...                                        ...
# AC141272.1                                 0.0
# AC023491.2                                 0.0
# AC007325.1                                 0.0
# AC007325.4                                 0.0
# AC007325.2                                 0.0
#
# index        AGATTGCTCTGCCAGG-HCA_A_GT12934998  \
# MIR1302-2HG                                0.0
# FAM138A                                    0.0
# OR4F5                                      0.0
# AL627309.1                                 0.0
# AL627309.3                                 0.0
# ...                                        ...
# AC141272.1                                 0.0
# AC023491.2                                 0.0
# AC007325.1                                 0.0
# AC007325.4                                 0.0
# AC007325.2                                 0.0
#
# index        AGGCCACTCCTATTCA-HCA_A_GT12934998  \
# MIR1302-2HG                                0.0
# FAM138A                                    0.0
# OR4F5                                      0.0
# AL627309.1                                 0.0
# AL627309.3                                 0.0
# ...                                        ...
# AC141272.1                                 0.0
# AC023491.2                                 0.0
# AC007325.1                                 0.0
# AC007325.4                                 0.0
# AC007325.2                                 0.0
#
# index        AGGCCGTGTTGTACAC-HCA_A_GT12934998  \
# MIR1302-2HG                                0.0
# FAM138A                                    0.0
# OR4F5                                      0.0
# AL627309.1                                 0.0
# AL627309.3                                 0.0
# ...                                        ...
# AC141272.1                                 0.0
# AC023491.2                                 0.0
# AC007325.1                                 0.0
# AC007325.4                                 0.0
# AC007325.2                                 0.0
#
# index        AGGGTGAGTGACTACT-HCA_A_GT12934998  ...  \
# MIR1302-2HG                                0.0  ...
# FAM138A                                    0.0  ...
# OR4F5                                      0.0  ...
# AL627309.1                                 0.0  ...
# AL627309.3                                 0.0  ...
# ...                                        ...  ...
# AC141272.1                                 0.0  ...
# AC023491.2                                 0.0  ...
# AC007325.1                                 0.0  ...
# AC007325.4                                 0.0  ...
# AC007325.2                                 0.0  ...
#
# index        TTTCCTCGTATATCCG-HT-188-Adult-Duo  \
# MIR1302-2HG                                0.0
# FAM138A                                    0.0
# OR4F5                                      0.0
# AL627309.1                                 0.0
# AL627309.3                                 0.0
# ...                                        ...
# AC141272.1                                 0.0
# AC023491.2                                 0.0
# AC007325.1                                 0.0
# AC007325.4                                 0.0
# AC007325.2                                 0.0
#
# index        TTTGCGCCACTAGTAC-HT-188-Adult-Duo  \
# MIR1302-2HG                                0.0
# FAM138A                                    0.0
# OR4F5                                      0.0
# AL627309.1                                 0.0
# AL627309.3                                 0.0
# ...                                        ...
# AC141272.1                                 0.0
# AC023491.2                                 0.0
# AC007325.1                                 0.0
# AC007325.4                                 0.0
# AC007325.2                                 0.0
#
# index        TTTGCGCCATCCGTGG-HT-188-Adult-Duo  \
# MIR1302-2HG                                0.0
# FAM138A                                    0.0
# OR4F5                                      0.0
# AL627309.1                                 0.0
# AL627309.3                                 0.0
# ...                                        ...
# AC141272.1                                 0.0
# AC023491.2                                 0.0
# AC007325.1                                 0.0
# AC007325.4                                 0.0
# AC007325.2                                 0.0
#
# index        TTTGCGCGTGAGTATA-HT-188-Adult-Duo  \
# MIR1302-2HG                                0.0
# FAM138A                                    0.0
# OR4F5                                      0.0
# AL627309.1                                 0.0
# AL627309.3                                 0.0
# ...                                        ...
# AC141272.1                                 0.0
# AC023491.2                                 0.0
# AC007325.1                                 0.0
# AC007325.4                                 0.0
# AC007325.2                                 0.0
#
# index        TTTGCGCTCAACACCA-HT-188-Adult-Duo  \
# MIR1302-2HG                                0.0
# FAM138A                                    0.0
# OR4F5                                      0.0
# AL627309.1                                 0.0
# AL627309.3                                 0.0
# ...                                        ...
# AC141272.1                                 0.0
# AC023491.2                                 0.0
# AC007325.1                                 0.0
# AC007325.4                                 0.0
# AC007325.2                                 0.0
#
# index        TTTGCGCTCTTGAGGT-HT-188-Adult-Duo  \
# MIR1302-2HG                                0.0
# FAM138A                                    0.0
# OR4F5                                      0.0
# AL627309.1                                 0.0
# AL627309.3                                 0.0
# ...                                        ...
# AC141272.1                                 0.0
# AC023491.2                                 0.0
# AC007325.1                                 0.0
# AC007325.4                                 0.0
# AC007325.2                                 0.0
#
# index        TTTGGTTAGAGTAATC-HT-188-Adult-Duo  \
# MIR1302-2HG                                0.0
# FAM138A                                    0.0
# OR4F5                                      0.0
# AL627309.1                                 0.0
# AL627309.3                                 0.0
# ...                                        ...
# AC141272.1                                 0.0
# AC023491.2                                 0.0
# AC007325.1                                 0.0
# AC007325.4                                 0.0
# AC007325.2                                 0.0
#
# index        TTTGGTTCAAGCCGCT-HT-188-Adult-Duo  \
# MIR1302-2HG                                0.0
# FAM138A                                    0.0
# OR4F5                                      0.0
# AL627309.1                                 0.0
# AL627309.3                                 0.0
# ...                                        ...
# AC141272.1                                 0.0
# AC023491.2                                 0.0
# AC007325.1                                 0.0
# AC007325.4                                 0.0
# AC007325.2                                 0.0
#
# index        TTTGTCACAAGCGAGT-HT-188-Adult-Duo  \
# MIR1302-2HG                                0.0
# FAM138A                                    0.0
# OR4F5                                      0.0
# AL627309.1                                 0.0
# AL627309.3                                 0.0
# ...                                        ...
# AC141272.1                                 0.0
# AC023491.2                                 0.0
# AC007325.1                                 0.0
# AC007325.4                                 0.0
# AC007325.2                                 0.0
#
# index        TTTGTCATCTCGCATC-HT-188-Adult-Duo
# MIR1302-2HG                                0.0
# FAM138A                                    0.0
# OR4F5                                      0.0
# AL627309.1                                 0.0
# AL627309.3                                 0.0
# ...                                        ...
# AC141272.1                                 0.0
# AC023491.2                                 0.0
# AC007325.1                                 0.0
# AC007325.4                                 0.0
# AC007325.2                                 0.0
#
# [36601 rows x 18889 columns]

# %%
df.to_csv('/home/jovyan/ao15/Megagut/Annotations_v3/disease_analysis/interactions/counts/pooled_healthy.remapped.allgenes.AP_SI.counts.csv')

# %%
df = pd.DataFrame(disease.X.todense(), index=disease.obs_names, columns=disease.var_names)
#tranpose
df = df.T
df
# Out:
# index        AAACCTGAGGCCCTCA-4918STDY7273964  \
# MIR1302-2HG                               0.0
# FAM138A                                   0.0
# OR4F5                                     0.0
# AL627309.1                                0.0
# AL627309.3                                0.0
# ...                                       ...
# AC141272.1                                0.0
# AC023491.2                                0.0
# AC007325.1                                0.0
# AC007325.4                                0.0
# AC007325.2                                0.0
#
# index        AAACGGGGTAAAGGAG-4918STDY7273964  \
# MIR1302-2HG                               0.0
# FAM138A                                   0.0
# OR4F5                                     0.0
# AL627309.1                                0.0
# AL627309.3                                0.0
# ...                                       ...
# AC141272.1                                0.0
# AC023491.2                                0.0
# AC007325.1                                0.0
# AC007325.4                                0.0
# AC007325.2                                0.0
#
# index        AAAGATGAGTCCAGGA-4918STDY7273964  \
# MIR1302-2HG                               0.0
# FAM138A                                   0.0
# OR4F5                                     0.0
# AL627309.1                                0.0
# AL627309.3                                0.0
# ...                                       ...
# AC141272.1                                0.0
# AC023491.2                                0.0
# AC007325.1                                0.0
# AC007325.4                                0.0
# AC007325.2                                0.0
#
# index        AAAGATGTCAAACAAG-4918STDY7273964  \
# MIR1302-2HG                               0.0
# FAM138A                                   0.0
# OR4F5                                     0.0
# AL627309.1                                0.0
# AL627309.3                                0.0
# ...                                       ...
# AC141272.1                                0.0
# AC023491.2                                0.0
# AC007325.1                                0.0
# AC007325.4                                0.0
# AC007325.2                                0.0
#
# index        AAAGATGTCAACGAAA-4918STDY7273964  \
# MIR1302-2HG                               0.0
# FAM138A                                   0.0
# OR4F5                                     0.0
# AL627309.1                                0.0
# AL627309.3                                0.0
# ...                                       ...
# AC141272.1                                0.0
# AC023491.2                                0.0
# AC007325.1                                0.0
# AC007325.4                                0.0
# AC007325.2                                0.0
#
# index        AAAGATGTCAGTCAGT-4918STDY7273964  \
# MIR1302-2HG                               0.0
# FAM138A                                   0.0
# OR4F5                                     0.0
# AL627309.1                                0.0
# AL627309.3                                0.0
# ...                                       ...
# AC141272.1                                0.0
# AC023491.2                                0.0
# AC007325.1                                0.0
# AC007325.4                                0.0
# AC007325.2                                0.0
#
# index        AAAGATGTCTAACTTC-4918STDY7273964  \
# MIR1302-2HG                               0.0
# FAM138A                                   0.0
# OR4F5                                     0.0
# AL627309.1                                0.0
# AL627309.3                                0.0
# ...                                       ...
# AC141272.1                                0.0
# AC023491.2                                0.0
# AC007325.1                                0.0
# AC007325.4                                0.0
# AC007325.2                                0.0
#
# index        AAAGCAAAGAGCTGGT-4918STDY7273964  \
# MIR1302-2HG                               0.0
# FAM138A                                   0.0
# OR4F5                                     0.0
# AL627309.1                                0.0
# AL627309.3                                0.0
# ...                                       ...
# AC141272.1                                0.0
# AC023491.2                                0.0
# AC007325.1                                0.0
# AC007325.4                                0.0
# AC007325.2                                0.0
#
# index        AAAGCAACACCATCCT-4918STDY7273964  \
# MIR1302-2HG                               0.0
# FAM138A                                   0.0
# OR4F5                                     0.0
# AL627309.1                                0.0
# AL627309.3                                0.0
# ...                                       ...
# AC141272.1                                0.0
# AC023491.2                                0.0
# AC007325.1                                0.0
# AC007325.4                                0.0
# AC007325.2                                0.0
#
# index        AAAGTAGAGAATGTTG-4918STDY7273964  ...  \
# MIR1302-2HG                               0.0  ...
# FAM138A                                   0.0  ...
# OR4F5                                     0.0  ...
# AL627309.1                                0.0  ...
# AL627309.3                                0.0  ...
# ...                                       ...  ...
# AC141272.1                                0.0  ...
# AC023491.2                                0.0  ...
# AC007325.1                                0.0  ...
# AC007325.4                                0.0  ...
# AC007325.2                                0.0  ...
#
# index        TTCCCAGGTTCCGGCA-GSM4766849  TTCGAAGAGGAGTAGA-GSM4766849  \
# MIR1302-2HG                          0.0                          0.0
# FAM138A                              0.0                          0.0
# OR4F5                                0.0                          0.0
# AL627309.1                           0.0                          0.0
# AL627309.3                           0.0                          0.0
# ...                                  ...                          ...
# AC141272.1                           0.0                          0.0
# AC023491.2                           0.0                          0.0
# AC007325.1                           0.0                          0.0
# AC007325.4                           0.0                          0.0
# AC007325.2                           0.0                          0.0
#
# index        TTCGGTCTCCAGAGGA-GSM4766849  TTCTACATCTTTAGTC-GSM4766849  \
# MIR1302-2HG                          0.0                          0.0
# FAM138A                              0.0                          0.0
# OR4F5                                0.0                          0.0
# AL627309.1                           0.0                          0.0
# AL627309.3                           0.0                          0.0
# ...                                  ...                          ...
# AC141272.1                           0.0                          0.0
# AC023491.2                           0.0                          0.0
# AC007325.1                           0.0                          0.0
# AC007325.4                           0.0                          0.0
# AC007325.2                           0.0                          0.0
#
# index        TTCTCAAGTGAGCGAT-GSM4766849  TTGAACGCAGTTAACC-GSM4766849  \
# MIR1302-2HG                          0.0                     0.000000
# FAM138A                              0.0                     0.000000
# OR4F5                                0.0                     0.000000
# AL627309.1                           0.0                     0.000000
# AL627309.3                           0.0                     0.000000
# ...                                  ...                          ...
# AC141272.1                           0.0                     0.000000
# AC023491.2                           0.0                     0.000000
# AC007325.1                           0.0                     0.000000
# AC007325.4                           0.0                     1.707043
# AC007325.2                           0.0                     0.000000
#
# index        TTGGCAACAGTGGAGT-GSM4766849  TTTACTGGTGGACGAT-GSM4766849  \
# MIR1302-2HG                          0.0                          0.0
# FAM138A                              0.0                          0.0
# OR4F5                                0.0                          0.0
# AL627309.1                           0.0                          0.0
# AL627309.3                           0.0                          0.0
# ...                                  ...                          ...
# AC141272.1                           0.0                          0.0
# AC023491.2                           0.0                          0.0
# AC007325.1                           0.0                          0.0
# AC007325.4                           0.0                          0.0
# AC007325.2                           0.0                          0.0
#
# index        TTTGGTTTCGGCCGAT-GSM4766849  TTTGTCAAGTTACCCA-GSM4766849
# MIR1302-2HG                          0.0                          0.0
# FAM138A                              0.0                          0.0
# OR4F5                                0.0                          0.0
# AL627309.1                           0.0                          0.0
# AL627309.3                           0.0                          0.0
# ...                                  ...                          ...
# AC141272.1                           0.0                          0.0
# AC023491.2                           0.0                          0.0
# AC007325.1                           0.0                          0.0
# AC007325.4                           0.0                          0.0
# AC007325.2                           0.0                          0.0
#
# [36601 rows x 19654 columns]

# %%
df.to_csv('/home/jovyan/ao15/Megagut/Annotations_v3/disease_analysis/interactions/counts/pooled_disease.remapped.allgenes.AP_SI.counts.csv')

# %%
meta = healthy.obs.level_3_annot
meta
# Out:
# index
# AACCGCGCAGTTTACG-HCA_A_GT12934998                  Monocyte
# AACTCTTCAAGCTGAG-HCA_A_GT12934998             Tnaive/cm_CD8
# ACACTGAGTAACGCGA-HCA_A_GT12934998                      Treg
# ACGAGGATCGGTCTAA-HCA_A_GT12934998    Megakaryocyte/platelet
# ACTGCTCAGTCCAGGA-HCA_A_GT12934998                        TA
#                                               ...
# TTTGCGCTCTTGAGGT-HT-188-Adult-Duo         Goblet_progenitor
# TTTGGTTAGAGTAATC-HT-188-Adult-Duo              B_plasma_IgG
# TTTGGTTCAAGCCGCT-HT-188-Adult-Duo              B_plasma_IgM
# TTTGTCACAAGCGAGT-HT-188-Adult-Duo           Epithelial_stem
# TTTGTCATCTCGCATC-HT-188-Adult-Duo           Epithelial_stem
# Name: level_3_annot, Length: 18889, dtype: object

# %%
meta.to_csv('/home/jovyan/ao15/Megagut/Annotations_v3/disease_analysis/interactions/meta/pooled_healthy.remapped.allgenes.AP_SI.meta.csv')

# %%
meta = disease.obs.level_3_annot
meta
# Out:
# index
# AAACCTGAGGCCCTCA-4918STDY7273964         gdT_naive
# AAACGGGGTAAAGGAG-4918STDY7273964           B_GC_II
# AAAGATGAGTCCAGGA-4918STDY7273964    Goblet_cycling
# AAAGATGTCAAACAAG-4918STDY7273964         Treg_IL10
# AAAGATGTCAACGAAA-4918STDY7273964            B_GC_I
#                                          ...
# TTGAACGCAGTTAACC-GSM4766849                NK_CD16
# TTGGCAACAGTGGAGT-GSM4766849               Monocyte
# TTTACTGGTGGACGAT-GSM4766849          NK_CD56bright
# TTTGGTTTCGGCCGAT-GSM4766849             Enterocyte
# TTTGTCAAGTTACCCA-GSM4766849           T/NK_cycling
# Name: level_3_annot, Length: 19654, dtype: object

# %%
meta.to_csv('/home/jovyan/ao15/Megagut/Annotations_v3/disease_analysis/interactions/meta/pooled_disease.remapped.allgenes.AP_SI.meta.csv')
