# %% [markdown]
# ## Checking for neutrophils in disease data, based on cells failing QC but annotated as neutrophils by celltypist

# %%
#%load_ext autoreload
#%autoreload 2
#%matplotlib inline

import os#, re, gc, joblib

import numpy as np
import numpy_groupies as npg
import scipy.sparse as sp
import pandas as pd
from sklearn.preprocessing import minmax_scale

import matplotlib.pyplot as plt
import seaborn as sn

import anndata

import scanpy as sc
import sctk as sk

# %%
# from matplotlib.backends.backend_pdf import PdfPages
from matplotlib import rcParams
from matplotlib.colors import ListedColormap

rcParams["pdf.fonttype"] = 42
rcParams["ps.fonttype"] = 42
expr_cmap = sk.expression_colormap()
np.set_printoptions(linewidth=150)
sc.settings.verbosity = 0

# %%
ad = sc.read("/lustre/scratch126/cellgen/team205/nh3/20220125_digestive_tract_integration/v2/h5ad/pooled/pooled_disease.gene_cellbender.post_qc.20220930.h5ad")

# %%
ad
# Out:
# AnnData object with n_obs × n_vars = 436488 × 36601
#     obs: 'latent_cell_probability', 'latent_RT_efficiency', 'cecilia22_predH', 'cecilia22_predH_prob', 'cecilia22_predH_uncertain', 'cecilia22_predL', 'cecilia22_predL_prob', 'cecilia22_predL_uncertain', 'elmentaite21_pred', 'elmentaite21_pred_prob', 'elmentaite21_pred_uncertain', 'suo22_pred', 'suo22_pred_prob', 'suo22_pred_uncertain', 'n_counts', 'log1p_n_counts', 'n_genes', 'log1p_n_genes', 'percent_mito', 'n_counts_mito', 'percent_ribo', 'n_counts_ribo', 'percent_hb', 'n_counts_hb', 'percent_top50', 'n_counts_raw', 'log1p_n_counts_raw', 'n_genes_raw', 'log1p_n_genes_raw', 'percent_mito_raw', 'n_counts_mito_raw', 'percent_ribo_raw', 'n_counts_ribo_raw', 'percent_hb_raw', 'n_counts_hb_raw', 'percent_top50_raw', 'n_counts_spliced', 'log1p_n_counts_spliced', 'n_genes_spliced', 'log1p_n_genes_spliced', 'percent_mito_spliced', 'n_counts_mito_spliced', 'percent_ribo_spliced', 'n_counts_ribo_spliced', 'percent_hb_spliced', 'n_counts_hb_spliced', 'percent_top50_spliced', 'n_counts_unspliced', 'log1p_n_counts_unspliced', 'n_genes_unspliced', 'log1p_n_genes_unspliced', 'percent_mito_unspliced', 'n_counts_mito_unspliced', 'percent_ribo_unspliced', 'n_counts_ribo_unspliced', 'percent_hb_unspliced', 'n_counts_hb_unspliced', 'percent_top50_unspliced', 'percent_soup', 'percent_spliced', 'qc_cluster', 'pass_auto_filter_mito20', 'good_qc_cluster_mito20', 'pass_auto_filter_mito50', 'good_qc_cluster_mito50', 'pass_auto_filter_mito80', 'good_qc_cluster_mito80', 'pass_auto_filter', 'good_qc_cluster', 'pass_default', 'sampleID', 'sourceID', 'donorID_original', 'study', 'donorID_corrected', 'donorID_unified', 'donor_category', 'donor_disease', 'organ_original', 'organ_unified', 'organ_broad', 'age_original', 'age_unified', 'age_continuousadult', 'age_continuousdev', 'sex', 'sample_type', 'sample_category', 'sample_retrieval', 'tissue_fraction', 'cell_fraction', 'cell_fraction_unified', 'cell_sorting', 'technology', 'include_150722'
#     var: 'gene_ids', 'feature_type', 'mito', 'ribo', 'hb', 'n_counts', 'n_counts_raw', 'n_counts_spliced', 'n_counts_unspliced', 'n_cells', 'n_cells_raw', 'n_cells_spliced', 'n_cells_unspliced', 'cc', 'ig', 'tcr'

# %%
obs = sk.read_h5ad(
    "/lustre/scratch126/cellgen/team205/nh3/20220125_digestive_tract_integration/v2/h5ad/pooled/pooled_disease.gene_cellbender.post_qc.20220930.h5ad", component="obs"
)

# %%
obs.columns
# Out:
# Index(['latent_cell_probability', 'latent_RT_efficiency', 'cecilia22_predH',
#        'cecilia22_predH_prob', 'cecilia22_predH_uncertain', 'cecilia22_predL',
#        'cecilia22_predL_prob', 'cecilia22_predL_uncertain',
#        'elmentaite21_pred', 'elmentaite21_pred_prob',
#        'elmentaite21_pred_uncertain', 'suo22_pred', 'suo22_pred_prob',
#        'suo22_pred_uncertain', 'n_counts', 'log1p_n_counts', 'n_genes',
#        'log1p_n_genes', 'percent_mito', 'n_counts_mito', 'percent_ribo',
#        'n_counts_ribo', 'percent_hb', 'n_counts_hb', 'percent_top50',
#        'n_counts_raw', 'log1p_n_counts_raw', 'n_genes_raw',
#        'log1p_n_genes_raw', 'percent_mito_raw', 'n_counts_mito_raw',
#        'percent_ribo_raw', 'n_counts_ribo_raw', 'percent_hb_raw',
#        'n_counts_hb_raw', 'percent_top50_raw', 'n_counts_spliced',
#        'log1p_n_counts_spliced', 'n_genes_spliced', 'log1p_n_genes_spliced',
#        'percent_mito_spliced', 'n_counts_mito_spliced', 'percent_ribo_spliced',
#        'n_counts_ribo_spliced', 'percent_hb_spliced', 'n_counts_hb_spliced',
#        'percent_top50_spliced', 'n_counts_unspliced',
#        'log1p_n_counts_unspliced', 'n_genes_unspliced',
#        'log1p_n_genes_unspliced', 'percent_mito_unspliced',
#        'n_counts_mito_unspliced', 'percent_ribo_unspliced',
#        'n_counts_ribo_unspliced', 'percent_hb_unspliced',
#        'n_counts_hb_unspliced', 'percent_top50_unspliced', 'percent_soup',
#        'percent_spliced', 'qc_cluster', 'pass_auto_filter_mito20',
#        'good_qc_cluster_mito20', 'pass_auto_filter_mito50',
#        'good_qc_cluster_mito50', 'pass_auto_filter_mito80',
#        'good_qc_cluster_mito80', 'pass_auto_filter', 'good_qc_cluster',
#        'pass_default', 'sampleID', 'sourceID', 'donorID_original', 'study',
#        'donorID_corrected', 'donorID_unified', 'donor_category',
#        'donor_disease', 'organ_original', 'organ_unified', 'organ_broad',
#        'age_original', 'age_unified', 'age_continuousadult',
#        'age_continuousdev', 'sex', 'sample_type', 'sample_category',
#        'sample_retrieval', 'tissue_fraction', 'cell_fraction',
#        'cell_fraction_unified', 'cell_sorting', 'technology',
#        'include_150722'],
#       dtype='object')

# %%
obs.suo22_pred.cat.categories.values
# Out:
# array(['B1', 'CD4+T', 'CD8+T', 'CYCLING_B', 'CYCLING_DC', 'CYCLING_EPITHELIUM', 'CYCLING_NK', 'CYCLING_T', 'DC1', 'DC2', 'DOUBLET',
#        'DOUBLET_LYMPHOID_MACROPHAGE', 'ENDOTHELIUM_I', 'ENDOTHELIUM_II', 'ENTEROENDOCRINE_I', 'EOSINOPHIL_BASOPHIL', 'EPITHELIUM_I', 'EPITHELIUM_II',
#        'FIBROBLAST_I', 'FIBROBLAST_IX', 'FIBROBLAST_VIII', 'FIBROBLAST_XI', 'GLIAL', 'HEPATOCYTE-LIKE', 'HIGH_MITO', 'ILC3', 'KERATINOCYTE',
#        'LARGE_PRE_B', 'LATE_ERY', 'LATE_MK', 'LMPP_MLP', 'LOW_QUALITY', 'LOW_QUALITY_MACROPHAGE', 'LOW_QUALITY_MID_ERY_(HIGH_RIBO)',
#        'MACROPHAGE_ERY', 'MACROPHAGE_LYVE1_HIGH', 'MACROPHAGE_MHCII_HIGH', 'MAST_CELL', 'MATURE_B', 'MESENCHYMAL_LYMPHOID_TISSUE_ORGANISER',
#        'MESOTHELIUM', 'MID_ERY', 'MIGRATORY_DC', 'MONOCYTE_III_IL1B', 'MYOFIBROBLAST', 'MYOFIBROBLAST_I', 'NK', 'OSTEOBLAST', 'OSTEOCLAST', 'PDC',
#        'PLASMA_B', 'SMOOTH_MUSCLE', 'TREG', 'TYPE_1_INNATE_T', 'TYPE_3_INNATE_T', 'VSMC_PERICYTE', 'VSMC_PERICYTE_III'], dtype=object)

# %%
suo22_neutrophil_counts = (
    obs[["sampleID", "suo22_pred", "good_qc_cluster_mito80"]]
    .value_counts(sort=False)
    .reset_index()
    .rename(columns={0: "count"})
    .loc[lambda x: x.suo22_pred.isin(["MONOCYTE_I_CXCR4", "MYELOCYTE", "NEUTROPHIL"])]
)

# %%
suo22_neutrophil_counts
# Out:
# Empty DataFrame
# Columns: [sampleID, suo22_pred, good_qc_cluster_mito80, count]
# Index: []

# %%
obs.elmentaite21_pred.cat.categories.values
# Out:
# array(['Activated CD4 T', 'Activated CD8 T', 'Adult Glia', 'BEST2+ Goblet cell', 'BEST4+ epithelial', 'CD8 Tmem', 'CLDN10+ cells', 'CLP',
#        'CX3CR1+ CD8 Tmem', 'Colonocyte', 'Contractile pericyte (PLN+)', 'Cycling B cell', 'Cycling plasma cell', 'D cells (SST+)', 'DZ GC cell',
#        'EC cells (TAC1+)', 'EECs', 'Enterocyte', 'FCRL4+ Memory B', 'FDC', 'Fetal arterial EC', 'GC B cell', 'Goblet cell', 'I cells (CCK+)', 'ILC3',
#        'IgA plasma cell', 'IgG plasma cell', 'IgM plasma cell', 'Immature B', 'L cells (PYY+)', 'LEC1 (ACKR4+)', 'LEC3 (ADGRG3+)', 'LEC6 (ADAMTS4+)',
#        'LYVE1+ Macrophage', 'LZ GC cell', 'Lymphoid DC', 'M/X cells (MLN/GHRL+)', 'MAIT cell', 'MMP9+ Inflammatory macrophage', 'Macrophages',
#        'Mast cell', 'Mature arterial EC', 'Mature venous EC', 'Memory B', 'Mesoderm 1 (HAND1+)', 'Mesoderm 2 (ZEB2+)', 'Mesothelium',
#        'Microfold cell', 'Monocytes', 'NK T cell', 'NK cell', 'Naive B', 'Paneth', 'Pericyte', 'Progenitor (NEUROG3+)', 'Proximal progenitor', 'RBC',
#        'SELL+ CD4 T', 'SELL+ CD8 T', 'SMC (PART1/CAPN3+)', 'SMC (PLPP2+)', 'STAT1+ Naive B', 'Stem cells', 'Stromal 1 (ADAMDEC1+)',
#        'Stromal 1 (CCL11+)', 'Stromal 2 (NPY+)', 'Stromal 3 (C7+)', 'Stromal 4 (MMP1+)', 'T reticular', 'TA', 'TRGV4 gdT', 'Tfh', 'Th1', 'Th17',
#        'Transitional Stromal 3 (C3+)', 'Treg', 'Tuft', 'arterial capillary', 'cDC1', 'cDC2', 'cycling stromal', 'gdT', 'myofibroblast',
#        'myofibroblast (RSPO2+)', 'pDC'], dtype=object)

# %%
elmentaite21_neutrophil_counts = (
    obs[["sampleID", "elmentaite21_pred", "good_qc_cluster_mito80"]]
    .value_counts(sort=False)
    .reset_index()
    .rename(columns={0: "count"})
    .loc[lambda x: x.elmentaite21_pred.isin(["Monocytes", "MPO+ mono-neutrophil"])]
)

# %%
elmentaite21_neutrophil_counts.loc[
    lambda x: x.elmentaite21_pred == "MPO+ mono-neutrophil"
].sort_values(
    ["elmentaite21_pred", "good_qc_cluster_mito80", "sampleID", "count"],
    ascending=[True, False, True, False],
)
# Out:
# Empty DataFrame
# Columns: [sampleID, elmentaite21_pred, good_qc_cluster_mito80, count]
# Index: []

# %%
suo22_neutrophil_counts.sort_values(
    ["suo22_pred", "good_qc_cluster_mito80", "sampleID", "count"],
    ascending=[True, False, True, False],
)
# Out:
# Empty DataFrame
# Columns: [sampleID, suo22_pred, good_qc_cluster_mito80, count]
# Index: []

# %%
neutrophil_obs = obs.loc[
    lambda x: (
        x.suo22_pred.isin(["MONOCYTE_I_CXCR4", "MYELOCYTE", "NEUTROPHIL"])
        | (x.elmentaite21_pred.isin(["MPO+ mono-neutrophil"]))
    )
    & ~x.good_qc_cluster_mito80
]

# %%
neutrophil_obs
# Out:
# Empty DataFrame
# Columns: [latent_cell_probability, latent_RT_efficiency, cecilia22_predH, cecilia22_predH_prob, cecilia22_predH_uncertain, cecilia22_predL, cecilia22_predL_prob, cecilia22_predL_uncertain, elmentaite21_pred, elmentaite21_pred_prob, elmentaite21_pred_uncertain, suo22_pred, suo22_pred_prob, suo22_pred_uncertain, n_counts, log1p_n_counts, n_genes, log1p_n_genes, percent_mito, n_counts_mito, percent_ribo, n_counts_ribo, percent_hb, n_counts_hb, percent_top50, n_counts_raw, log1p_n_counts_raw, n_genes_raw, log1p_n_genes_raw, percent_mito_raw, n_counts_mito_raw, percent_ribo_raw, n_counts_ribo_raw, percent_hb_raw, n_counts_hb_raw, percent_top50_raw, n_counts_spliced, log1p_n_counts_spliced, n_genes_spliced, log1p_n_genes_spliced, percent_mito_spliced, n_counts_mito_spliced, percent_ribo_spliced, n_counts_ribo_spliced, percent_hb_spliced, n_counts_hb_spliced, percent_top50_spliced, n_counts_unspliced, log1p_n_counts_unspliced, n_genes_unspliced, log1p_n_genes_unspliced, percent_mito_unspliced, n_counts_mito_unspliced, percent_ribo_unspliced, n_counts_ribo_unspliced, percent_hb_unspliced, n_counts_hb_unspliced, percent_top50_unspliced, percent_soup, percent_spliced, qc_cluster, pass_auto_filter_mito20, good_qc_cluster_mito20, pass_auto_filter_mito50, good_qc_cluster_mito50, pass_auto_filter_mito80, good_qc_cluster_mito80, pass_auto_filter, good_qc_cluster, pass_default, sampleID, sourceID, donorID_original, study, donorID_corrected, donorID_unified, donor_category, donor_disease, organ_original, organ_unified, organ_broad, age_original, age_unified, age_continuousadult, age_continuousdev, sex, sample_type, sample_category, sample_retrieval, tissue_fraction, cell_fraction, cell_fraction_unified, cell_sorting, technology, include_150722]
# Index: []
#
# [0 rows x 95 columns]

# %%
obs_healthy = sk.read_h5ad(
    "/lustre/scratch126/cellgen/team205/nh3/20220125_digestive_tract_integration/v2/h5ad/pooled/pooled_healthy.gene_cellbender.post_qc.20220909.h5ad", component="obs"
)

# %%
suo22_neutrophil_counts = (
    obs_healthy[["sampleID", "suo22_pred", "good_qc_cluster_mito80"]]
    .value_counts(sort=False)
    .reset_index()
    .rename(columns={0: "count"})
    .loc[lambda x: x.suo22_pred.isin(["MONOCYTE_I_CXCR4", "MYELOCYTE", "NEUTROPHIL"])]
)

# %%
suo22_neutrophil_counts.sort_values(
    ["suo22_pred", "good_qc_cluster_mito80", "sampleID", "count"],
    ascending=[True, False, True, False],
)
# Out:
#                      sampleID        suo22_pred  good_qc_cluster_mito80  count
# 77         6-Int-Fresh-Sorted  MONOCYTE_I_CXCR4                    True     41
# 1270          4918STDY7717783  MONOCYTE_I_CXCR4                    True     11
# 1379          4918STDY7717787  MONOCYTE_I_CXCR4                    True     24
# 1419          4918STDY7717788  MONOCYTE_I_CXCR4                    True     45
# 1538          4918STDY7718973  MONOCYTE_I_CXCR4                    True     21
# 1581          4918STDY7718974  MONOCYTE_I_CXCR4                    True     23
# 5977         HCA_A_GT12934997  MONOCYTE_I_CXCR4                    True     10
# 6000         HCA_A_GT12934998  MONOCYTE_I_CXCR4                    True     10
# 6041         HCA_A_GT12934999  MONOCYTE_I_CXCR4                    True      7
# 6138         HCA_A_GT12935002  MONOCYTE_I_CXCR4                    True      7
# 6399        HT228-fetal-ileum  MONOCYTE_I_CXCR4                    True     19
# 6839    HT-232_stomach_antrum  MONOCYTE_I_CXCR4                    True      4
# 7248   HT-243_small-intestine  MONOCYTE_I_CXCR4                    True     31
# 1269          4918STDY7717783  MONOCYTE_I_CXCR4                   False      1
# 1378          4918STDY7717787  MONOCYTE_I_CXCR4                   False      4
# 1418          4918STDY7717788  MONOCYTE_I_CXCR4                   False      1
# 1537          4918STDY7718973  MONOCYTE_I_CXCR4                   False      5
# 1580          4918STDY7718974  MONOCYTE_I_CXCR4                   False      8
# 2409           FCA_gut8015061  MONOCYTE_I_CXCR4                   False      4
# 5976         HCA_A_GT12934997  MONOCYTE_I_CXCR4                   False    246
# 5999         HCA_A_GT12934998  MONOCYTE_I_CXCR4                   False    941
# 6040         HCA_A_GT12934999  MONOCYTE_I_CXCR4                   False    102
# 6137         HCA_A_GT12935002  MONOCYTE_I_CXCR4                   False     13
# 6398        HT228-fetal-ileum  MONOCYTE_I_CXCR4                   False      7
# 6838    HT-232_stomach_antrum  MONOCYTE_I_CXCR4                   False      5
# 7247   HT-243_small-intestine  MONOCYTE_I_CXCR4                   False     14
# 10480               scrEXT003  MONOCYTE_I_CXCR4                   False      7
# 1862               ERR4161418         MYELOCYTE                    True      6
# 5979         HCA_A_GT12934997         MYELOCYTE                    True      7
# 6002         HCA_A_GT12934998         MYELOCYTE                    True      2
# 6043         HCA_A_GT12934999         MYELOCYTE                    True     11
# 5978         HCA_A_GT12934997         MYELOCYTE                   False     48
# 6001         HCA_A_GT12934998         MYELOCYTE                   False     13
# 6042         HCA_A_GT12934999         MYELOCYTE                   False     22
# 5981         HCA_A_GT12934997        NEUTROPHIL                    True      1
# 6045         HCA_A_GT12934999        NEUTROPHIL                    True     28
# 5980         HCA_A_GT12934997        NEUTROPHIL                   False    124
# 6003         HCA_A_GT12934998        NEUTROPHIL                   False     89
# 6044         HCA_A_GT12934999        NEUTROPHIL                   False    168
# 9852                  PT-64_2        NEUTROPHIL                   False     15

# %%
elmentaite21_neutrophil_counts = (
    obs_healthy[["sampleID", "elmentaite21_pred", "good_qc_cluster_mito80"]]
    .value_counts(sort=False)
    .reset_index()
    .rename(columns={0: "count"})
    .loc[lambda x: x.elmentaite21_pred.isin(["Monocytes", "MPO+ mono-neutrophil"])]
)

# %%
elmentaite21_neutrophil_counts.loc[
    lambda x: x.elmentaite21_pred == "MPO+ mono-neutrophil"
].sort_values(
    ["elmentaite21_pred", "good_qc_cluster_mito80", "sampleID", "count"],
    ascending=[True, False, True, False],
)
# Out:
#               sampleID     elmentaite21_pred  good_qc_cluster_mito80  count
# 504    4918STDY7317587  MPO+ mono-neutrophil                    True     17
# 2245        ERR3245543  MPO+ mono-neutrophil                    True     43
# 7491  HCA_A_GT12934997  MPO+ mono-neutrophil                    True      7
# 7508  HCA_A_GT12934998  MPO+ mono-neutrophil                    True      2
# 7538  HCA_A_GT12934999  MPO+ mono-neutrophil                    True     11
# 503    4918STDY7317587  MPO+ mono-neutrophil                   False      4
# 2244        ERR3245543  MPO+ mono-neutrophil                   False     52
# 7490  HCA_A_GT12934997  MPO+ mono-neutrophil                   False     48
# 7507  HCA_A_GT12934998  MPO+ mono-neutrophil                   False     13
# 7537  HCA_A_GT12934999  MPO+ mono-neutrophil                   False     22

# %%
neutrophil_obs = obs_healthy.loc[
    lambda x: (
        x.suo22_pred.isin(["MONOCYTE_I_CXCR4", "MYELOCYTE", "NEUTROPHIL"])
        | (x.elmentaite21_pred.isin(["MPO+ mono-neutrophil"]))
    )
    & ~x.good_qc_cluster_mito80
]

# %%
neutrophil_obs
# Out:
#                                     latent_cell_probability  \
# index
# AAACCTGCAACTGCGC-HCA_A_GT12934997                  0.999836
# AAACCTGCATGGTAGG-HCA_A_GT12934997                  0.999973
# AAAGATGAGGACAGCT-HCA_A_GT12934997                  0.999740
# AAAGTAGTCAACGAAA-HCA_A_GT12934997                  0.999746
# AACACGTAGAGACTAT-HCA_A_GT12934997                  0.999990
# ...                                                     ...
# CTACATTGTCTGCCAG-HT228-fetal-ileum                 0.999368
# CTCGTCATCACCTTAT-HT228-fetal-ileum                 0.999655
# TGACAACAGAAGGGTA-HT228-fetal-ileum                 0.999645
# TTCTACACATGACATC-HT228-fetal-ileum                 0.999886
# TTTCCTCGTTCGTGAT-HT228-fetal-ileum                 0.999772
#
#                                     latent_RT_efficiency cecilia22_predH  \
# index
# AAACCTGCAACTGCGC-HCA_A_GT12934997               0.857807       Monocytes
# AAACCTGCATGGTAGG-HCA_A_GT12934997               1.019605       Monocytes
# AAAGATGAGGACAGCT-HCA_A_GT12934997               0.827556       Monocytes
# AAAGTAGTCAACGAAA-HCA_A_GT12934997               0.844798       Monocytes
# AACACGTAGAGACTAT-HCA_A_GT12934997               1.046917       Monocytes
# ...                                                  ...             ...
# CTACATTGTCTGCCAG-HT228-fetal-ileum              0.764953       Monocytes
# CTCGTCATCACCTTAT-HT228-fetal-ileum              0.781690       Monocytes
# TGACAACAGAAGGGTA-HT228-fetal-ileum              0.805281       Monocytes
# TTCTACACATGACATC-HT228-fetal-ileum              1.197547       Monocytes
# TTTCCTCGTTCGTGAT-HT228-fetal-ileum              0.635153       Monocytes
#
#                                     cecilia22_predH_prob  \
# index
# AAACCTGCAACTGCGC-HCA_A_GT12934997               0.990857
# AAACCTGCATGGTAGG-HCA_A_GT12934997               0.995862
# AAAGATGAGGACAGCT-HCA_A_GT12934997               0.987690
# AAAGTAGTCAACGAAA-HCA_A_GT12934997               0.904525
# AACACGTAGAGACTAT-HCA_A_GT12934997               0.999294
# ...                                                  ...
# CTACATTGTCTGCCAG-HT228-fetal-ileum              0.290352
# CTCGTCATCACCTTAT-HT228-fetal-ileum              0.732175
# TGACAACAGAAGGGTA-HT228-fetal-ileum              0.999954
# TTCTACACATGACATC-HT228-fetal-ileum              0.988781
# TTTCCTCGTTCGTGAT-HT228-fetal-ileum              0.627918
#
#                                    cecilia22_predH_uncertain  \
# index
# AAACCTGCAACTGCGC-HCA_A_GT12934997                  Monocytes
# AAACCTGCATGGTAGG-HCA_A_GT12934997                  Monocytes
# AAAGATGAGGACAGCT-HCA_A_GT12934997                  Monocytes
# AAAGTAGTCAACGAAA-HCA_A_GT12934997                  Monocytes
# AACACGTAGAGACTAT-HCA_A_GT12934997                  Monocytes
# ...                                                      ...
# CTACATTGTCTGCCAG-HT228-fetal-ileum                 Uncertain
# CTCGTCATCACCTTAT-HT228-fetal-ileum                 Monocytes
# TGACAACAGAAGGGTA-HT228-fetal-ileum                 Monocytes
# TTCTACACATGACATC-HT228-fetal-ileum                 Monocytes
# TTTCCTCGTTCGTGAT-HT228-fetal-ileum                 Monocytes
#
#                                         cecilia22_predL  cecilia22_predL_prob  \
# index
# AAACCTGCAACTGCGC-HCA_A_GT12934997   Classical monocytes              0.922057
# AAACCTGCATGGTAGG-HCA_A_GT12934997   Classical monocytes              0.995586
# AAAGATGAGGACAGCT-HCA_A_GT12934997   Classical monocytes              0.968681
# AAAGTAGTCAACGAAA-HCA_A_GT12934997   Classical monocytes              0.408359
# AACACGTAGAGACTAT-HCA_A_GT12934997   Classical monocytes              0.961076
# ...                                                 ...                   ...
# CTACATTGTCTGCCAG-HT228-fetal-ileum  Classical monocytes              0.554634
# CTCGTCATCACCTTAT-HT228-fetal-ileum  Classical monocytes              0.912063
# TGACAACAGAAGGGTA-HT228-fetal-ileum  Classical monocytes              0.999600
# TTCTACACATGACATC-HT228-fetal-ileum  Classical monocytes              0.988855
# TTTCCTCGTTCGTGAT-HT228-fetal-ileum  Classical monocytes              0.823076
#
#                                    cecilia22_predL_uncertain  \
# index
# AAACCTGCAACTGCGC-HCA_A_GT12934997        Classical monocytes
# AAACCTGCATGGTAGG-HCA_A_GT12934997        Classical monocytes
# AAAGATGAGGACAGCT-HCA_A_GT12934997        Classical monocytes
# AAAGTAGTCAACGAAA-HCA_A_GT12934997        Classical monocytes
# AACACGTAGAGACTAT-HCA_A_GT12934997        Classical monocytes
# ...                                                      ...
# CTACATTGTCTGCCAG-HT228-fetal-ileum       Classical monocytes
# CTCGTCATCACCTTAT-HT228-fetal-ileum       Classical monocytes
# TGACAACAGAAGGGTA-HT228-fetal-ileum       Classical monocytes
# TTCTACACATGACATC-HT228-fetal-ileum       Classical monocytes
# TTTCCTCGTTCGTGAT-HT228-fetal-ileum       Classical monocytes
#
#                                    elmentaite21_pred  elmentaite21_pred_prob  \
# index
# AAACCTGCAACTGCGC-HCA_A_GT12934997          Monocytes                0.780143
# AAACCTGCATGGTAGG-HCA_A_GT12934997          Monocytes                0.414794
# AAAGATGAGGACAGCT-HCA_A_GT12934997          Monocytes                0.879200
# AAAGTAGTCAACGAAA-HCA_A_GT12934997          Monocytes                0.982469
# AACACGTAGAGACTAT-HCA_A_GT12934997          Monocytes                0.095466
# ...                                              ...                     ...
# CTACATTGTCTGCCAG-HT228-fetal-ileum         Monocytes                0.963459
# CTCGTCATCACCTTAT-HT228-fetal-ileum         Monocytes                0.941024
# TGACAACAGAAGGGTA-HT228-fetal-ileum         Monocytes                1.000000
# TTCTACACATGACATC-HT228-fetal-ileum         Monocytes                0.999451
# TTTCCTCGTTCGTGAT-HT228-fetal-ileum         Monocytes                0.973734
#
#                                     ...     sex            sample_type  \
# index                               ...
# AAACCTGCAACTGCGC-HCA_A_GT12934997   ...  Female  Organ_donor_resection
# AAACCTGCATGGTAGG-HCA_A_GT12934997   ...  Female  Organ_donor_resection
# AAAGATGAGGACAGCT-HCA_A_GT12934997   ...  Female  Organ_donor_resection
# AAAGTAGTCAACGAAA-HCA_A_GT12934997   ...  Female  Organ_donor_resection
# AACACGTAGAGACTAT-HCA_A_GT12934997   ...  Female  Organ_donor_resection
# ...                                 ...     ...                    ...
# CTACATTGTCTGCCAG-HT228-fetal-ileum  ...    Male  Organ_donor_resection
# CTCGTCATCACCTTAT-HT228-fetal-ileum  ...    Male  Organ_donor_resection
# TGACAACAGAAGGGTA-HT228-fetal-ileum  ...    Male  Organ_donor_resection
# TTCTACACATGACATC-HT228-fetal-ileum  ...    Male  Organ_donor_resection
# TTTCCTCGTTCGTGAT-HT228-fetal-ileum  ...    Male  Organ_donor_resection
#
#                                      sample_category sample_retrieval  \
# index
# AAACCTGCAACTGCGC-HCA_A_GT12934997   Non_pathological              DBD
# AAACCTGCATGGTAGG-HCA_A_GT12934997   Non_pathological              DBD
# AAAGATGAGGACAGCT-HCA_A_GT12934997   Non_pathological              DBD
# AAAGTAGTCAACGAAA-HCA_A_GT12934997   Non_pathological              DBD
# AACACGTAGAGACTAT-HCA_A_GT12934997   Non_pathological              DBD
# ...                                              ...              ...
# CTACATTGTCTGCCAG-HT228-fetal-ileum  Non_pathological      Unspecified
# CTCGTCATCACCTTAT-HT228-fetal-ileum  Non_pathological      Unspecified
# TGACAACAGAAGGGTA-HT228-fetal-ileum  Non_pathological      Unspecified
# TTCTACACATGACATC-HT228-fetal-ileum  Non_pathological      Unspecified
# TTTCCTCGTTCGTGAT-HT228-fetal-ileum  Non_pathological      Unspecified
#
#                                     tissue_fraction  cell_fraction  \
# index
# AAACCTGCAACTGCGC-HCA_A_GT12934997        Epithelium          Total
# AAACCTGCATGGTAGG-HCA_A_GT12934997        Epithelium          Total
# AAAGATGAGGACAGCT-HCA_A_GT12934997        Epithelium          Total
# AAAGTAGTCAACGAAA-HCA_A_GT12934997        Epithelium          Total
# AACACGTAGAGACTAT-HCA_A_GT12934997        Epithelium          Total
# ...                                             ...            ...
# CTACATTGTCTGCCAG-HT228-fetal-ileum   Full_thickness          Total
# CTCGTCATCACCTTAT-HT228-fetal-ileum   Full_thickness          Total
# TGACAACAGAAGGGTA-HT228-fetal-ileum   Full_thickness          Total
# TTCTACACATGACATC-HT228-fetal-ileum   Full_thickness          Total
# TTTCCTCGTTCGTGAT-HT228-fetal-ileum   Full_thickness          Total
#
#                                     cell_fraction_unified  cell_sorting  \
# index
# AAACCTGCAACTGCGC-HCA_A_GT12934997                   Total          None
# AAACCTGCATGGTAGG-HCA_A_GT12934997                   Total          None
# AAAGATGAGGACAGCT-HCA_A_GT12934997                   Total          None
# AAAGTAGTCAACGAAA-HCA_A_GT12934997                   Total          None
# AACACGTAGAGACTAT-HCA_A_GT12934997                   Total          None
# ...                                                   ...           ...
# CTACATTGTCTGCCAG-HT228-fetal-ileum                  Total          None
# CTCGTCATCACCTTAT-HT228-fetal-ileum                  Total          None
# TGACAACAGAAGGGTA-HT228-fetal-ileum                  Total          None
# TTCTACACATGACATC-HT228-fetal-ileum                  Total          None
# TTTCCTCGTTCGTGAT-HT228-fetal-ileum                  Total          None
#
#                                     technology     include_150722
# index
# AAACCTGCAACTGCGC-HCA_A_GT12934997       10X_5p  healthy_reference
# AAACCTGCATGGTAGG-HCA_A_GT12934997       10X_5p  healthy_reference
# AAAGATGAGGACAGCT-HCA_A_GT12934997       10X_5p  healthy_reference
# AAAGTAGTCAACGAAA-HCA_A_GT12934997       10X_5p  healthy_reference
# AACACGTAGAGACTAT-HCA_A_GT12934997       10X_5p  healthy_reference
# ...                                        ...                ...
# CTACATTGTCTGCCAG-HT228-fetal-ileum    10X_3pv2  healthy_reference
# CTCGTCATCACCTTAT-HT228-fetal-ileum    10X_3pv2  healthy_reference
# TGACAACAGAAGGGTA-HT228-fetal-ileum    10X_3pv2  healthy_reference
# TTCTACACATGACATC-HT228-fetal-ileum    10X_3pv2  healthy_reference
# TTTCCTCGTTCGTGAT-HT228-fetal-ileum    10X_3pv2  healthy_reference
#
# [1893 rows x 95 columns]
